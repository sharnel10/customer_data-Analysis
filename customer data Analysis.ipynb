# %%
import pandas as pd
import os

# %%
customer_data = pd.read_csv("sample_dataset.csv")
customer_data
# Out:
#        Customer ID       Name    Surname Gender   Birthdate  \
# 0           752858       Sean  Rodriguez      F  2002-10-20
# 1            26381   Michelle     Phelps    NaN  1985-10-24
# 2           305449      Jacob   Williams      M  1981-10-25
# 3           988259     Nathan     Snyder      M  1977-10-26
# 4           764762    Crystal      Knapp      F  1951-11-02
# ...            ...        ...        ...    ...         ...
# 49995       891845  Christine      Leach      F  1997-10-21
# 49996       800560       Anna      Allen      F  1999-10-21
# 49997       133285     Nicole   Franklin      M  1979-10-26
# 49998       616122      Maria     Keller      M  1981-10-25
# 49999       832184      Billy     Walker      F  1958-10-31
#
#        Transaction Amount        Date                 Merchant Name  \
# 0                   35.47  2023-04-03                 Smith-Russell
# 1                 2552.72  2023-07-17        Peck, Spence and Young
# ...

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         50000 non-null  int64
#  1   Name                50000 non-null  object
#  2   Surname             50000 non-null  object
#  3   Gender              44953 non-null  object
#  4   Birthdate           50000 non-null  object
#  5   Transaction Amount  50000 non-null  float64
#  6   Date                50000 non-null  object
#  7   Merchant Name       50000 non-null  object
#  8   Category            50000 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.4+ MB

# %%
customer_data.describe()
# Out:
#         Customer ID  Transaction Amount
# count   50000.00000        50000.000000
# mean   500136.79696          442.119239
# std    288232.43164          631.669724
# min        29.00000            5.010000
# 25%    251191.50000           79.007500
# 50%    499520.50000          182.195000
# 75%    749854.25000          470.515000
# max    999997.00000         2999.880000

# %%
customer_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Length: 50000, dtype: bool

# %%
customer_data.head(100)
# Out:
#     Customer ID       Name    Surname Gender   Birthdate  Transaction Amount  \
# 0        752858       Sean  Rodriguez      F  2002-10-20               35.47
# 1         26381   Michelle     Phelps    NaN  1985-10-24             2552.72
# 2        305449      Jacob   Williams      M  1981-10-25              115.97
# 3        988259     Nathan     Snyder      M  1977-10-26               11.31
# 4        764762    Crystal      Knapp      F  1951-11-02               62.21
# ..          ...        ...        ...    ...         ...                 ...
# 95       838514     Andrew  Armstrong      M  2004-10-19              231.35
# 96       981118    Anthony     Arnold      M  1971-10-28             2362.42
# 97       658610     Nicole   Peterson      M  1965-10-29              395.33
# 98       463162  Stephanie     Miller    NaN  1958-10-31              958.43
# 99       707412      Derek   Thompson      F  1985-10-24               94.93
#
# ...

# %% [markdown]
# ### Task #1: Cleaning the data

# %%
customer_data = customer_data.drop(columns = ['Gender'])

# %%
customer_data
# Out:
#        Customer ID       Name    Surname   Birthdate  Transaction Amount  \
# 0           752858       Sean  Rodriguez  2002-10-20               35.47
# 1            26381   Michelle     Phelps  1985-10-24             2552.72
# 2           305449      Jacob   Williams  1981-10-25              115.97
# 3           988259     Nathan     Snyder  1977-10-26               11.31
# 4           764762    Crystal      Knapp  1951-11-02               62.21
# ...            ...        ...        ...         ...                 ...
# 49995       891845  Christine      Leach  1997-10-21              108.74
# 49996       800560       Anna      Allen  1999-10-21              133.66
# 49997       133285     Nicole   Franklin  1979-10-26              464.29
# 49998       616122      Maria     Keller  1981-10-25              472.57
# 49999       832184      Billy     Walker  1958-10-31              270.67
#
#              Date                 Merchant Name     Category
# ...

# %%
customer_data['Month'] = customer_data['Date'].str[5:7]
customer_data['Month'] = customer_data['Month'].astype('int32')
customer_data
# Out:
#        Customer ID       Name    Surname   Birthdate  Transaction Amount  \
# 0           752858       Sean  Rodriguez  2002-10-20               35.47
# 1            26381   Michelle     Phelps  1985-10-24             2552.72
# 2           305449      Jacob   Williams  1981-10-25              115.97
# 3           988259     Nathan     Snyder  1977-10-26               11.31
# 4           764762    Crystal      Knapp  1951-11-02               62.21
# ...            ...        ...        ...         ...                 ...
# 49995       891845  Christine      Leach  1997-10-21              108.74
# 49996       800560       Anna      Allen  1999-10-21              133.66
# 49997       133285     Nicole   Franklin  1979-10-26              464.29
# 49998       616122      Maria     Keller  1981-10-25              472.57
# 49999       832184      Billy     Walker  1958-10-31              270.67
#
#              Date                 Merchant Name     Category  Month
# ...

# %%
def merchant(Merchant_Name):
    return Merchant_Name.split(' ')[0].split('-')[0].split(',')[0]

customer_data['Merchandise'] = customer_data['Merchant Name'].apply(lambda x: merchant(x))
customer_data
# Out:
#        Customer ID       Name    Surname   Birthdate  Transaction Amount  \
# 0           752858       Sean  Rodriguez  2002-10-20               35.47
# 1            26381   Michelle     Phelps  1985-10-24             2552.72
# 2           305449      Jacob   Williams  1981-10-25              115.97
# 3           988259     Nathan     Snyder  1977-10-26               11.31
# 4           764762    Crystal      Knapp  1951-11-02               62.21
# ...            ...        ...        ...         ...                 ...
# 49995       891845  Christine      Leach  1997-10-21              108.74
# 49996       800560       Anna      Allen  1999-10-21              133.66
# 49997       133285     Nicole   Franklin  1979-10-26              464.29
# 49998       616122      Maria     Keller  1981-10-25              472.57
# 49999       832184      Billy     Walker  1958-10-31              270.67
#
#              Date                 Merchant Name     Category  Month  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         50000 non-null  int64
#  1   Name                50000 non-null  object
#  2   Surname             50000 non-null  object
#  3   Birthdate           50000 non-null  object
#  4   Transaction Amount  50000 non-null  float64
#  5   Date                50000 non-null  object
#  6   Merchant Name       50000 non-null  object
#  7   Category            50000 non-null  object
#  8   Month               50000 non-null  int32
#  9   Merchandise         50000 non-null  object
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 3.6+ MB

# %% [markdown]
# ## Question 1: Highest Generated Income by Category

# %%
results = customer_data.groupby('Category').sum()
results
# Out:
# C:\Users\sharon\AppData\Local\Temp\ipykernel_6528\1597667319.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results = customer_data.groupby('Category').sum()
#              Customer ID  Transaction Amount  Month
# Category
# Clothing      4178451482          1319342.47  43333
# Cosmetic      4132115839           876672.44  43157
# Electronics   4132876707          4394092.10  43358
# Market        4164595419          2151134.42  44309
# Restaurant    4226967847           464488.60  44209
# Travel        4171832554         12900231.94  44246

# %%
category = ['Clothing', 'Cosmetics', 'Electronics', 'Market', 'Restaurant', 'Travel']
plt.bar(category, results['Transaction Amount'])
plt.xticks(category)
plt.ylabel('Highest Sales in USD ($)')
plt.xlabel('Category')
plt.title('Highest Generated Income by Category')
plt.show()

# %% [markdown]
# ## Question 2: Best Month For Sales?

# %%
sales = customer_data.groupby('Month').sum()
sales
# Out:
# C:\Users\sharon\AppData\Local\Temp\ipykernel_6528\742285254.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales = customer_data.groupby('Month').sum()
#        Customer ID  Transaction Amount
# Month
# 1       2734889905          2345228.21
# 2       2430110753          2148030.95
# 3       2728304340          2396963.31
# 4       2550147532          2289731.30
# 5       2754081319          2460816.56
# 6       2667299985          2254592.41
# 7       2699553055          2475041.53
# 8       2703841708          2391450.20
# 9       2558304083          2274245.66
# 10      1180307168          1069861.84

# %%
months = range(1,11)

plt.bar(months, sales['Transaction Amount'])
plt.xticks(months)
plt.ylabel('Highest Sales in USD ($)')
plt.xlabel('Months')
plt.title('Best Month For Sales')
plt.show()
